# %%
import cv2
from ultralytics import YOLO
import firebase_admin
from firebase_admin import credentials, db
import time
from threading import Timer

# Global flag to indicate whether the program is running
program_running = True

# Check if Firebase app is already initialized
if not firebase_admin._apps:
    # Initialize Firebase
    cred = credentials.Certificate("feeder-d63d2-firebase-adminsdk-ybhos-10e79d725f.json")
    firebase_admin.initialize_app(cred, {
        'databaseURL': 'https://feeder-d63d2-default-rtdb.firebaseio.com/'
    })

# Load the YOLOv8 model
model = YOLO("best_model.pt")

# Open the webcam (use 0 for the default webcam)
cap = cv2.VideoCapture(0)

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Define the colors for each label
label_colors = {
    "Unseated": (0, 255, 0),  # Green
    "Seated": (0, 0, 255),    # Red
}

def draw_boxes(frame, boxes, labels):
    for box, label in zip(boxes, labels):
        color = label_colors[label]
        x1, y1, x2, y2 = map(int, box)
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)

def display_label_count(frame, label_counts):
    y_offset = 30
    for label, count in label_counts.items():
        text = f"{label}: {count}"
        cv2.putText(frame, text, (10, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
        y_offset += 30

# Function to send data to Firebase
def send_data_to_firebase(label_counts):
    global program_running
    if program_running:
        ref = db.reference('label_counts')
        timestamp = int(time.time())
        ref.child(str(timestamp)).set(label_counts)

# Initialize label_counts
label_counts = {"Unseated": 0, "Seated": 0}

# Timer function to send data every 30 seconds
def start_timer():
    global program_running
    if program_running:
        Timer(5, start_timer).start()
        send_data_to_firebase(label_counts)

# Start the timer
start_timer()

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the webcam
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)

        # Extract the bounding boxes and labels
        boxes = results[0].boxes.xyxy.numpy()
        if hasattr(results[0], 'names'):
            label_ids = results[0].boxes.cls.numpy()
            labels = [results[0].names[int(label_id)] for label_id in label_ids]
        else:
            labels = []

        # Draw the bounding boxes with label-specific colors
        draw_boxes(frame, boxes, labels)

        # Reset label_counts
        label_counts = {"Unseated": 0, "Seated": 0}

        # Count the number of occurrences of each label
        for label in labels:
            if label in label_counts:
                label_counts[label] += 1

        # Display the label counts on the frame
        display_label_count(frame, label_counts)

        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if there's an error reading the frame
        print("Error: Could not read frame from webcam.")
        break

# Set the program_running flag to False to stop sending data to Firebase
program_running = False

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 2024-07-07 20:52:36.038 Python[29295:559464] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# 0: 480x800 (no detections), 226.4ms
# Speed: 4.4ms preprocess, 226.4ms inference, 1126.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 218.5ms
# Speed: 3.3ms preprocess, 218.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 208.6ms
# Speed: 3.1ms preprocess, 208.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 207.8ms
# Speed: 2.9ms preprocess, 207.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 212.7ms
# Speed: 3.7ms preprocess, 212.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 218.6ms
# Speed: 3.6ms preprocess, 218.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 206.5ms
# Speed: 3.2ms preprocess, 206.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 208.7ms
# Speed: 3.1ms preprocess, 208.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.4ms
# Speed: 3.3ms preprocess, 210.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 215.8ms
# Speed: 2.9ms preprocess, 215.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 212.9ms
# Speed: 3.5ms preprocess, 212.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 211.6ms
# Speed: 2.9ms preprocess, 211.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 207.7ms
# Speed: 2.9ms preprocess, 207.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 212.5ms
# Speed: 2.8ms preprocess, 212.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 214.1ms
# Speed: 3.2ms preprocess, 214.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 212.7ms
# Speed: 3.3ms preprocess, 212.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 214.2ms
# Speed: 3.1ms preprocess, 214.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 216.3ms
# Speed: 2.9ms preprocess, 216.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 212.6ms
# Speed: 3.0ms preprocess, 212.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 214.1ms
# Speed: 3.1ms preprocess, 214.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 216.2ms
# Speed: 3.7ms preprocess, 216.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 212.6ms
# Speed: 3.4ms preprocess, 212.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 209.9ms
# Speed: 2.9ms preprocess, 209.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.6ms
# Speed: 2.9ms preprocess, 210.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 211.3ms
# Speed: 3.2ms preprocess, 211.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 211.9ms
# Speed: 2.7ms preprocess, 211.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 206.6ms
# Speed: 2.8ms preprocess, 206.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.2ms
# Speed: 2.7ms preprocess, 210.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 207.9ms
# Speed: 3.2ms preprocess, 207.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 214.1ms
# Speed: 3.1ms preprocess, 214.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 209.3ms
# Speed: 3.2ms preprocess, 209.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 209.9ms
# Speed: 3.3ms preprocess, 209.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 211.0ms
# Speed: 4.0ms preprocess, 211.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 208.6ms
# Speed: 3.2ms preprocess, 208.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 211.2ms
# Speed: 3.4ms preprocess, 211.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 213.7ms
# Speed: 3.1ms preprocess, 213.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 209.1ms
# Speed: 3.2ms preprocess, 209.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 Seated, 1 Unseated, 208.3ms
# Speed: 3.2ms preprocess, 208.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 Seated, 1 Unseated, 211.6ms
# Speed: 2.8ms preprocess, 211.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 Unseated, 213.7ms
# Speed: 3.1ms preprocess, 213.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 209.8ms
# Speed: 2.7ms preprocess, 209.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 Unseated, 207.6ms
# Speed: 3.3ms preprocess, 207.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 207.3ms
# Speed: 3.2ms preprocess, 207.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 208.0ms
# Speed: 2.9ms preprocess, 208.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 207.1ms
# Speed: 3.4ms preprocess, 207.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 Unseated, 208.7ms
# Speed: 2.8ms preprocess, 208.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 Seated, 1 Unseated, 211.3ms
# Speed: 3.4ms preprocess, 211.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 Seated, 1 Unseated, 211.1ms
# Speed: 2.8ms preprocess, 211.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 Seated, 1 Unseated, 207.0ms
# Speed: 3.7ms preprocess, 207.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 Seated, 206.2ms
# Speed: 3.4ms preprocess, 206.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 Seated, 211.1ms
# Speed: 2.6ms preprocess, 211.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 Seated, 209.5ms
# Speed: 3.1ms preprocess, 209.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 Seated, 209.3ms
# Speed: 2.9ms preprocess, 209.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 Seated, 1 Unseated, 207.6ms
# Speed: 2.7ms preprocess, 207.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 Seated, 1 Unseated, 214.3ms
# Speed: 2.7ms preprocess, 214.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 Seated, 209.6ms
# Speed: 2.9ms preprocess, 209.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.5ms
# Speed: 2.8ms preprocess, 210.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 208.6ms
# Speed: 2.7ms preprocess, 208.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 211.0ms
# Speed: 3.5ms preprocess, 211.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.8ms
# Speed: 2.8ms preprocess, 210.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 216.4ms
# Speed: 3.1ms preprocess, 216.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 213.7ms
# Speed: 3.0ms preprocess, 213.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.5ms
# Speed: 3.2ms preprocess, 210.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 211.6ms
# Speed: 2.7ms preprocess, 211.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.9ms
# Speed: 3.5ms preprocess, 210.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 211.5ms
# Speed: 2.8ms preprocess, 211.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.1ms
# Speed: 2.8ms preprocess, 210.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 208.9ms
# Speed: 3.2ms preprocess, 208.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.9ms
# Speed: 3.2ms preprocess, 210.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 209.9ms
# Speed: 3.5ms preprocess, 209.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.6ms
# Speed: 2.8ms preprocess, 210.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 213.9ms
# Speed: 3.0ms preprocess, 213.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 211.5ms
# Speed: 3.3ms preprocess, 211.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 211.0ms
# Speed: 2.8ms preprocess, 211.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 208.5ms
# Speed: 2.8ms preprocess, 208.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 211.7ms
# Speed: 2.9ms preprocess, 211.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.9ms
# Speed: 3.4ms preprocess, 210.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 211.6ms
# Speed: 3.0ms preprocess, 211.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 212.3ms
# Speed: 2.8ms preprocess, 212.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 219.7ms
# Speed: 2.9ms preprocess, 219.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 215.4ms
# Speed: 2.9ms preprocess, 215.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 214.6ms
# Speed: 3.3ms preprocess, 214.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.1ms
# Speed: 3.2ms preprocess, 210.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 212.7ms
# Speed: 3.1ms preprocess, 212.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 214.1ms
# Speed: 3.3ms preprocess, 214.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 213.6ms
# Speed: 3.4ms preprocess, 213.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 218.6ms
# Speed: 2.9ms preprocess, 218.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 219.0ms
# Speed: 2.8ms preprocess, 219.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 216.5ms
# Speed: 3.0ms preprocess, 216.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 209.2ms
# Speed: 2.8ms preprocess, 209.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 214.5ms
# Speed: 3.4ms preprocess, 214.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 213.5ms
# Speed: 2.7ms preprocess, 213.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.5ms
# Speed: 2.8ms preprocess, 210.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 213.3ms
# Speed: 3.2ms preprocess, 213.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 217.1ms
# Speed: 3.1ms preprocess, 217.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 214.0ms
# Speed: 2.8ms preprocess, 214.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 219.6ms
# Speed: 2.7ms preprocess, 219.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 214.7ms
# Speed: 3.5ms preprocess, 214.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 222.3ms
# Speed: 3.3ms preprocess, 222.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 219.3ms
# Speed: 2.8ms preprocess, 219.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 222.8ms
# Speed: 2.9ms preprocess, 222.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 220.6ms
# Speed: 3.0ms preprocess, 220.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 222.5ms
# Speed: 3.3ms preprocess, 222.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 213.2ms
# Speed: 3.7ms preprocess, 213.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 219.9ms
# Speed: 3.6ms preprocess, 219.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 212.3ms
# Speed: 2.9ms preprocess, 212.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 220.0ms
# Speed: 3.5ms preprocess, 220.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.6ms
# Speed: 3.3ms preprocess, 210.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.7ms
# Speed: 2.9ms preprocess, 210.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 217.5ms
# Speed: 4.0ms preprocess, 217.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.3ms
# Speed: 3.5ms preprocess, 210.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 215.8ms
# Speed: 2.8ms preprocess, 215.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 217.6ms
# Speed: 2.9ms preprocess, 217.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 211.5ms
# Speed: 2.8ms preprocess, 211.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 212.2ms
# Speed: 3.5ms preprocess, 212.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 209.8ms
# Speed: 2.9ms preprocess, 209.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 205.8ms
# Speed: 2.8ms preprocess, 205.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 207.5ms
# Speed: 3.3ms preprocess, 207.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 214.8ms
# Speed: 2.8ms preprocess, 214.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 225.2ms
# Speed: 3.3ms preprocess, 225.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 219.2ms
# Speed: 3.9ms preprocess, 219.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 215.4ms
# Speed: 3.4ms preprocess, 215.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 208.0ms
# Speed: 2.9ms preprocess, 208.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.3ms
# Speed: 3.2ms preprocess, 210.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 215.5ms
# Speed: 3.4ms preprocess, 215.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 210.8ms
# Speed: 3.0ms preprocess, 210.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 209.7ms
# Speed: 2.8ms preprocess, 209.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 211.5ms
# Speed: 2.9ms preprocess, 211.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 211.5ms
# Speed: 3.4ms preprocess, 211.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 212.2ms
# Speed: 2.9ms preprocess, 212.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 800)
